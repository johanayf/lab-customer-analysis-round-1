# %%
#Importing Pandas
import pandas as pd

# %%
data1 = pd.read_csv('/Users/johanayf/Desktop/lab-customer-analysis-round-1/files_for_lab/csv_files/file1.csv')
data2 = pd.read_csv('/Users/johanayf/Desktop/lab-customer-analysis-round-1/files_for_lab/csv_files/file2.csv')
data3 = pd.read_csv('/Users/johanayf/Desktop/lab-customer-analysis-round-1/files_for_lab/csv_files/file3.csv')

# %%
data1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
data2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
data3.head(1)
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
#
#    Total Claim Amount Vehicle Class
# 0               499.2  Two-Door Car

# %%
#Reorganizing Data2, Data3
data1.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
data2 = data2[['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
       'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
       'Policy Type', 'Vehicle Class', 'Total Claim Amount']]

# %%
data3 = data3[['Customer', 'State', 'Gender', 'Education', 'Customer Lifetime Value',
       'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
       'Policy Type', 'Vehicle Class', 'Total Claim Amount']]

# %%
data3
# Out:
#      Customer       State Gender             Education  \
# 0     SA25987  Washington      M  High School or Below
# 1     TB86706     Arizona      M                Master
# 2     ZL73902      Nevada      F              Bachelor
# 3     KX23516  California      F  High School or Below
# 4     FN77294  California      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                 3479.137523       0                   104
# 1                 2502.637401       0                    66
# 2                 3265.156348   25820                    82
# ...

# %%
data4=data3

# %%
#rename columns 
data4 = data4.rename(columns={'State': 'ST', 'Gender': 'GENDER'})

# %%
data3=data4

# %%
data1.head(1)
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  RB50392  Washington    NaN    Master                     NaN     0.0
#
#    Monthly Premium Auto Number of Open Complaints    Policy Type  \
# 0                1000.0                    1/0/00  Personal Auto
#
#    Vehicle Class  Total Claim Amount
# 0  Four-Door Car            2.704934

# %%
data2.head(1)
# Out:
#   Customer       ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873  Arizona      F  Bachelor              323912.47%   16061
#
#    Monthly Premium Auto Number of Open Complaints    Policy Type  \
# 0                    88                    1/0/00  Personal Auto
#
#    Vehicle Class  Total Claim Amount
# 0  Four-Door Car               633.6

# %%
data3.head(1)
# Out:
#   Customer          ST GENDER             Education  Customer Lifetime Value  \
# 0  SA25987  Washington      M  High School or Below              3479.137523
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
#
#   Vehicle Class  Total Claim Amount
# 0  Two-Door Car               499.2

# %%
data = pd.concat([data1,data2,data3], axis = 0)

# %%
data
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
type(data1.columns[0])
# Out:
# str

# %%
#finding out the type of the column
data.dtypes
# Out:
# Customer                      object
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value       object
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints     object
# Policy Type                   object
# Vehicle Class                 object
# Total Claim Amount           float64
# dtype: object

# %%
#questions: if I put print, this is different
data.dtypes['Customer']
# Out:
# dtype('O')

# %%
print(data.dtypes['Customer'])
# Out:
# object

# %%
# Which columns are numerical? 
data.select_dtypes('float64')
# Out:
#        Income  Monthly Premium Auto  Total Claim Amount
# 0         0.0                1000.0            2.704934
# 1         0.0                  94.0         1131.464935
# 2     48767.0                 108.0          566.472247
# 3         0.0                 106.0          529.881344
# 4     36357.0                  68.0           17.269323
# ...       ...                   ...                 ...
# 7065  71941.0                  73.0          198.234764
# 7066  21604.0                  79.0          379.200000
# 7067      0.0                  85.0          790.784983
# 7068  21941.0                  96.0          691.200000
# 7069      0.0                  77.0          369.600000
#
# [12074 rows x 3 columns]

# %%
# Which columns are numerical? 
for a in data.columns:
    if data.dtypes[a]=="float64": 
        print (a)
# Out:
# Income
# Monthly Premium Auto
# Total Claim Amount

# %%
#Which columns are categorical:'ST', 'GENDER', 'Education','Policy Type', 'Vehicle Class'

# %%
#Understand the meaning of all columns

# %%
data.isna().sum()
# Out:
# Customer                     2937
# ST                           2937
# GENDER                       3059
# Education                    2937
# Customer Lifetime Value      2944
# Income                       2937
# Monthly Premium Auto         2937
# Number of Open Complaints    2937
# Policy Type                  2937
# Vehicle Class                2937
# Total Claim Amount           2937
# dtype: int64

# %%
#- Delete the column education and the number of open complaints from the dataframe.
data = data.drop(['Education','Total Claim Amount'], axis=1)

# %%
#  - Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change `dtype` to `numerical` type.

# %%
#dataa['Customer Lifetime Value'] = pd.to_numeric(dataa['Customer Lifetime Value'], errors = 'coerce')

# %%
data['Customer Lifetime Value'] = data['Customer Lifetime Value'].str.replace('%','')
data['CLV']=data['Customer Lifetime Value']*100

# %%
#Check for duplicate rows in the data and remove if any.
data=data.drop_duplicates(subset=['Customer'])

# %%
#Filter out the data for customers who have an income of 0 or less.
data = data[data['Income']>0]

# %%
data
# Out:
#      Customer          ST GENDER Customer Lifetime Value   Income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F               697953.59      0.0
# 2     AI49188      Nevada      F              1288743.17  48767.0
# 3     WW63253  California      M               764586.18      0.0
# 4     GA49547  Washington      M               536307.65  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M                     NaN  71941.0
# 7066  PK87824  California      F                     NaN  21604.0
# 7067  TD14365  California      M                     NaN      0.0
# 7068  UP19263  California      M                     NaN  21941.0
# 7069  Y167826  California      M                     NaN      0.0
#
#       Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0                   1000.0                    1/0/00   Personal Auto
# ...

# %%
#pushing update git back
